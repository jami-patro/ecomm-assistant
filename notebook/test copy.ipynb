# %%
print("ok")
# Out:
# ok

# %%
b64="..."

# %%
pip install numpy
# Out:
# 218.53s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import base64
import numpy as np

decoded = base64.b64decode(b64)
vector = np.frombuffer(decoded, dtype=np.float32)
print(vector.tolist())
# Out:
# [3.5442644912703214e-13, -26601811083264.0, -5534349312.0, -1.0340604610944822e+29, 9.520395542494953e-05, 1.26179715428843e-22, 1.873995097412262e-05, 9.139701325524748e-32, -6.37335870123934e-06, 5.073296296953522e-11, -1.9801808400713642e+36, 100923826176.0, -6.593799071197282e-07, 3.211479503316644e-22, -2.3254236139432032e-21, 4.6878757224380984e-18, -1.8018256184836399e+25, -4057.3896484375, -54517293056.0, -2.806750090963091e-25, 2.0487273336144973e-11, 0.0001791295944713056, -1.7144354783494437e-13, -3.041128229581499e-19, -2.038454674781326e+37, -0.15257544815540314, 2.413273727435889e-30, -2.607098432314952e-27, 2.2241718278935683e-19, -1.0080314472894472e+37, 0.00046153541188687086, -3.0868208000654887e-22, -9.000071404556674e-32, 2.139769886736384e+17, -2.2752231222086205e+18, -513927040.0, 1.944906216522213e-06, -4.993625354988841e+32, 2.6492323002003104e-08, -1969943.625, -2.263595030148413e-36, -1.5800243616104126, -2.8985340062699517e+38, -0.11415906995534897, -5.9202
# ...
